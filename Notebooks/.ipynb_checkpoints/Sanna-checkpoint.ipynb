# %%
import numpy as np
import networkx as nx
from networkx.algorithms import bipartite
import matplotlib.pyplot as plt
from collections import Counter
import pandas as pd
from scipy.stats import linregress
from scipy.optimize import curve_fit
import powerlaw as pl

# %%
DATA = '../Data/out.moreno_crime_crime'
ROLE = '../Data/rel.moreno_crime_crime.person.role'
NAME = '../Data/ent.moreno_crime_crime.person.name'
SEX =  '../Data/ent.moreno_crime_crime.person.sex'

# %%
def fu(x, a, l):
    """A custom function which is a power law with its exponential truncation. From 'Atlas for the Aspiring
    Network Scientist' Chapter 6
    """
    return (x ** a) * np.exp(-l * x) 

def log_f(x, a, l):
    """The Logarithm of f, used to fit the log of the CCDF using curve_fit"""
    return np.log10(f(x, a, l))

# %%
with open(DATA) as f:
    data = f.read().splitlines()
    
with open(ROLE) as f:
    role = f.read().splitlines()
    
with open(NAME) as f:
    name = f.read().splitlines()
    
with open(SEX) as f:
    sex = f.read().splitlines()
    
for i in range(len(data)):
    data[i] = 'p' + data[i] # adds 'p' to the People nodes to differentiate them

# %%
B = nx.read_edgelist(data) # read edgelist in
print(len(B.nodes()), len(B.edges())) # sanity check (1380, 1476)
# Out:
# 1380 1476

# %%
graph = np.loadtxt(DATA, dtype=str)
a = np.unique(graph[:,0]) # people nodes
b = np.unique(graph[:,1]) # crime nodes
a = ['p' + a for a in a] # add string to differentiate

print(f"There are {len(a)} unique people and {len(b)} unique crime events.")
# Out:
# There are 829 unique people and 551 unique crime events.

# %%
G = nx.Graph()

# add nodes
for j in range(len(a)):
    G.add_node(a[j], bipartite=0, data=True, name=name[j], sex=sex[j]) #Add attributes name and sex

G.add_nodes_from(b, bipartite=1, data=True)

# add edges
i = 0
for edge in B.edges():
    G.add_edge(edge[0], edge[1], role=role[i]) # why role is in a list?
    i+=1

# %%
# sanity check
print(
    'Num. of nodes: {} \nNum. of edges: {} \nIs bipartite? {} \nIs connected? {}'.format(
        G.number_of_nodes(), 
        G.number_of_edges(), 
        nx.is_bipartite(G),
        nx.is_connected(G)
        )
    )
# Out:
# Num. of nodes: 1380
# Num. of edges: 1476
# Is bipartite? True
# Is connected? False

# %%
top_nodes = {n for n, d in G.nodes(data=True) if d["bipartite"] == 0} # people
bottom_nodes = set(G) - top_nodes # crimes

# %%
print(nx.get_node_attributes(G, 'name')['p1']) # check name of person 'p1' = 'AbelDennis'
print(nx.get_node_attributes(G, 'sex')['p1']) # check sex of person 'p1' = '1'
# Out:
# AbelDennis
# 1

# %%
nx.get_edge_attributes(G, 'role')['p1', '1']
# check role of edge between person p1 and crime 1 = 'Suspect'
# Out:
# 'Suspect'

# %%
e_p = []
e_c = []
for k in G.nodes():
    if G.nodes[k]["bipartite"] == 0:
        e_p.append(len(G.edges(k)))
    else:
        e_c.append(len(G.edges(k)))

e_cc = Counter(e_c)
plt.scatter(e_cc.keys(), e_cc.values())
plt.title('number of people involved in each crime')
plt.xlabel('Number of people')
plt.ylabel('Count');

# %%
e_pc = Counter(e_p)
plt.scatter(e_pc.keys(), e_pc.values())
plt.title('number of crimes each person has involvement in')
plt.xlabel('Number of crimes')
plt.ylabel('Count');

# %%
top_nodes = {n for n, d in G.nodes(data=True) if d["bipartite"] == 0}
bottom_nodes = set(G) - top_nodes

# %%
P = bipartite.weighted_projected_graph(G, top_nodes)
print(len(P.nodes()))
nx.draw(P, node_size=20)
# Out:
# 829

# %%
C = bipartite.weighted_projected_graph(G, bottom_nodes)
print(len(C.nodes))
nx.draw(C, node_size=20)
# Out:
# 551

# %%
# components in the graph sorted in descendent order
Gcc = sorted(nx.connected_components(G), key=len, reverse=True)
# selecting the biggest component
G0 = G.subgraph(Gcc[0])
len(G0.nodes)
# Out:
# 1263

# %%
top_nodes_gcc = {n for n, d in G0.nodes(data=True) if d["bipartite"] == 0}
bottom_nodes_gcc = set(G0) - top_nodes_gcc

len(top_nodes_gcc), len(bottom_nodes_gcc)
# Out:
# (754, 509)

# %%
# plot only biggest component
P = bipartite.weighted_projected_graph(G0, top_nodes_gcc)
print(len(P.nodes()))
nx.draw(P, node_size=20)
# Out:
# 754

# %%
node_neighbors = {n: len(set(G.neighbors(n))) for n in top_nodes_gcc}
maxnode = max(node_neighbors, key = node_neighbors.get)
print(maxnode, node_neighbors[maxnode])

node_neighbors = {n: len(set(G.neighbors(n))) for n in bottom_nodes_gcc}
maxnode = max(node_neighbors, key = node_neighbors.get)
print(maxnode, node_neighbors[maxnode])
# Out:
# p815 25
# 110 18

# %%
## Seperating layers

victims = [e[0] for e in nx.get_edge_attributes(G0, 'role') if nx.get_edge_attributes(G, 'role')[e] == 'Victim' or  nx.get_edge_attributes(G, 'role')[e] == 'Victim Suspect']
suspects = [e[0] for e in nx.get_edge_attributes(G0, 'role') if nx.get_edge_attributes(G, 'role')[e] == 'Suspect' or  nx.get_edge_attributes(G, 'role')[e] == 'Victim Suspect']
witnesses = [e[0] for e in nx.get_edge_attributes(G0, 'role') if nx.get_edge_attributes(G, 'role')[e] == 'Witness']

# %%
print(f'Number of victims {len(victims)}, unique {len(set(victims))}')
print(f'number of suspects {len(suspects)}, unique {len(set(suspects))}')
print(f'number of witnesses {len(witnesses)}, unique {len(set(witnesses))}')
print(f'Total number {len(suspects + witnesses + victims)}, unique {len(set(suspects + witnesses + victims))}')
# Out:
# Number of victims 557, unique 374
# number of suspects 680, unique 448
# number of witnesses 179, unique 155
# Total number 1416, unique 754

# %%
other = [e[0] for e in G0.edges() if e[0] not in victims and e[0] not in suspects and e[0] not in witnesses]
         
print(len(other))#sanity check that all people nodes are accounted for
# Out:
# 0

# %%
v = Counter(victims)
v_top = v.most_common(43) #victim at least 3 times
v_top
# Out:
# [('p815', 11),
#  ('p220', 9),
#  ('p356', 6),
#  ('p404', 6),
#  ('p425', 6),
#  ('p474', 6),
#  ('p497', 6),
#  ('p715', 6),
#  ('p190', 5),
#  ('p549', 5),
#  ('p56', 5),
#  ('p88', 5),
#  ('p10', 4),
#  ('p115', 4),
#  ('p155', 4),
#  ('p2', 4),
#  ('p214', 4),
#  ('p291', 4),
#  ('p336', 4),
#  ('p37', 4),
#  ('p413', 4),
#  ('p414', 4),
#  ('p514', 4),
#  ('p533', 4),
#  ('p592', 4),
#  ('p62', 4),
#  ('p690', 4),
#  ('p696', 4),
#  ('p221', 3),
#  ('p242', 3),
#  ('p277', 3),
#  ('p370', 3),
#  ('p384', 3),
#  ('p452', 3),
#  ('p51', 3),
#  ('p515', 3),
#  ('p572', 3),
#  ('p642', 3),
#  ('p659', 3),
#  ('p729', 3),
#  ('p767', 3),
#  ('p797', 3),
#  ('p811', 3)]

# %%
s = Counter(suspects)
s_top = s.most_common(44) #suspect at least 3 times
s_top
# Out:
# [('p2', 17),
#  ('p815', 12),
#  ('p425', 9),
#  ('p695', 9),
#  ('p514', 8),
#  ('p531', 8),
#  ('p220', 6),
#  ('p715', 6),
#  ('p108', 5),
#  ('p56', 5),
#  ('p592', 5),
#  ('p696', 5),
#  ('p74', 5),
#  ('p10', 4),
#  ('p115', 4),
#  ('p356', 4),
#  ('p37', 4),
#  ('p474', 4),
#  ('p51', 4),
#  ('p549', 4),
#  ('p577', 4),
#  ('p659', 4),
#  ('p67', 4),
#  ('p690', 4),
#  ('p729', 4),
#  ('p88', 4),
#  ('p106', 3),
#  ('p128', 3),
#  ('p159', 3),
#  ('p174', 3),
#  ('p303', 3),
#  ('p333', 3),
#  ('p336', 3),
#  ('p384', 3),
#  ('p396', 3),
#  ('p404', 3),
#  ('p410', 3),
#  ('p411', 3),
#  ('p536', 3),
#  ('p572', 3),
#  ('p584', 3),
#  ('p600', 3),
#  ('p663', 3),
#  ('p788', 3)]

# %%
w = Counter(witnesses)
w.most_common(10)
# Out:
# [('p79', 5),
#  ('p56', 4),
#  ('p425', 3),
#  ('p736', 3),
#  ('p112', 2),
#  ('p129', 2),
#  ('p159', 2),
#  ('p17', 2),
#  ('p220', 2),
#  ('p277', 2)]

# %%
def gendercount(node_list, G):
    '''takes a list of nodes with a "sex" attribute, and a graph, G and returns list of (males, females)'''
    female = []
    male = []
    
    for person in node_list:
        if nx.get_node_attributes(G, 'sex')[person] == '0':
            female.append(person)
        else:
            male.append(person)
            
    return male, female

# %%
sus = [s[0] for s in s_top]
vic = [v[0] for v in v_top]

vic_sus = [x for x in sus if x in vic]

male, female = gendercount(vic_sus, G)
        
print(f'There are {len(female)} females and {len(male)} males \nwho were victims at least 3 times \nand suspects at least 3 times')
# Out:
# There are 3 females and 21 males
# who were victims at least 3 times
# and suspects at least 3 times

# %%
v_male, v_female = gendercount(vic, G)
        
print(f'There are {len(v_female)} females and {len(v_male)} males who were victims at least 3 times')
# Out:
# There are 9 females and 34 males who were victims at least 3 times

# %%
s_male, s_female = gendercount(sus, G)
        
print(f'There are {len(s_female)} females and {len(s_male)} males who were suspects at least 3 times')
# Out:
# There are 11 females and 33 males who were suspects at least 3 times

# %%
#s_male, s_female

# %%
A = {}
for node in top_nodes:
    #print(node)
    A[node] = []
    for edge in G.edges(node):
        try:
            A[node].append(nx.get_edge_attributes(G, 'role')[edge])
            #print(nx.get_edge_attributes(G, 'weight')[edge])
        except: pass

# %%
def top(l):
    return Counter(l).most_common()

for a,b in sorted(A.items()):
    print(a, top(b))
# Out:
# p1 [('Suspect', 2), ('Victim', 2)]
# p10 [('Suspect', 3), ('Victim', 3), ('Witness', 1), ('Victim Suspect', 1)]
# p100 [('Suspect', 1)]
# p101 [('Witness', 1), ('Suspect', 1)]
# p102 [('Victim', 1)]
# p103 [('Witness', 1)]
# p104 [('Witness', 1), ('Victim', 1)]
# p105 [('Witness', 1)]
# p106 [('Suspect', 3)]
# p107 [('Witness', 1)]
# p108 [('Suspect', 5), ('Victim', 1)]
# p109 [('Witness', 1)]
# p11 [('Suspect', 1)]
# p110 [('Victim', 1)]
# p111 [('Suspect', 1)]
# p112 [('Witness', 2), ('Suspect', 1), ('Victim', 1)]
# p113 [('Suspect', 1)]
# p114 [('Suspect', 1), ('Victim', 1)]
# p115 [('Victim', 4), ('Suspect', 4), ('Witness', 1)]
# p116 [('Victim', 1)]
# p117 [('Witness', 1), ('Suspect', 1)]
# p118 [('Witness', 1)]
# p119 [('Victim', 2)]
# p12 [('Victim', 2), ('Witness', 1)]
# p120 [('Victim', 1)]
# p121 [('Victim', 1)]
# p122 [('Suspect', 1)]
# p123 [('Suspect', 1)]
# p124 [('Suspect', 1)]
# p125 [('Victim', 1)]
# p126 [('Victim', 1)]
# p127 [('Suspect', 1)]
# p128 [('Suspect', 3), ('Victim', 2), ('Witness', 1)]
# p129 [('Suspect', 2), ('Witness', 2), ('Victim', 1)]
# p13 [('Victim', 1)]
# p130 [('Witness', 1)]
# p131 [('Victim', 2), ('Suspect', 2)]
# p132 [('Suspect', 1)]
# p133 [('Witness', 1)]
# p134 [('Victim', 1)]
# p135 [('Victim', 1)]
# p136 [('Suspect', 1)]
# p137 [('Victim', 1)]
# p138 [('Victim', 1)]
# p139 [('Suspect', 1)]
# p14 [('Suspect', 1)]
# p140 [('Witness', 1)]
# p141 [('Victim', 1)]
# p142 [('Victim', 1)]
# p143 [('Victim', 1)]
# p144 [('Suspect', 1)]
# p145 [('Suspect', 1), ('Victim', 1)]
# p146 [('Victim', 5), ('Suspect', 2), ('Victim Suspect', 1)]
# p147 [('Suspect', 1)]
# p148 [('Suspect', 1)]
# p149 [('Suspect', 1)]
# p15 [('Suspect', 1)]
# p150 [('Suspect', 1)]
# p151 [('Victim', 1)]
# p152 [('Victim', 2), ('Witness', 1)]
# p153 [('Victim', 1)]
# p154 [('Witness', 1)]
# p155 [('Victim', 4), ('Suspect', 1)]
# p156 [('Suspect', 1)]
# p157 [('Suspect', 1)]
# p158 [('Victim', 1)]
# p159 [('Suspect', 3), ('Victim', 2), ('Witness', 2)]
# p16 [('Victim', 1)]
# p160 [('Suspect', 1)]
# p161 [('Suspect', 1)]
# p162 [('Suspect', 2)]
# p163 [('Suspect', 1)]
# p164 [('Suspect', 1)]
# p165 [('Suspect', 1)]
# p166 [('Suspect', 1)]
# p167 [('Suspect', 1), ('Victim', 1)]
# p168 [('Suspect', 1)]
# p169 [('Suspect', 1)]
# p17 [('Suspect', 2), ('Witness', 2), ('Victim', 1)]
# p170 [('Victim', 1)]
# p171 [('Victim', 1), ('Suspect', 1)]
# p172 [('Witness', 1)]
# p173 [('Suspect', 1)]
# p174 [('Suspect', 3), ('Witness', 1)]
# p175 [('Suspect', 1)]
# p176 [('Witness', 1)]
# p177 [('Victim', 1)]
# p178 [('Suspect', 1)]
# p179 [('Victim', 1)]
# p18 [('Suspect', 1)]
# p180 [('Victim', 1)]
# p181 [('Suspect', 1)]
# p182 [('Victim', 1)]
# p183 [('Victim', 1)]
# p184 [('Witness', 1), ('Suspect', 1)]
# p185 [('Suspect', 1)]
# p186 [('Victim', 1)]
# p187 [('Suspect', 1)]
# p188 [('Suspect', 1)]
# p189 [('Suspect', 1)]
# p19 [('Victim Suspect', 1)]
# p190 [('Victim', 4), ('Victim Suspect', 1), ('Suspect', 1)]
# p191 [('Victim', 1)]
# p192 [('Suspect', 1)]
# p193 [('Victim', 1)]
# p194 [('Witness', 1)]
# p195 [('Victim', 1)]
# p196 [('Suspect', 1)]
# p197 [('Victim', 1)]
# p198 [('Victim', 1)]
# p199 [('Suspect', 1), ('Witness', 1)]
# p2 [('Suspect', 17), ('Victim', 4), ('Witness', 1)]
# p20 [('Suspect', 1)]
# p200 [('Victim', 1)]
# p201 [('Suspect', 1)]
# p202 [('Suspect', 2), ('Witness', 1)]
# p203 [('Suspect', 1)]
# p204 [('Victim', 1)]
# p205 [('Suspect', 1)]
# p206 [('Witness', 1)]
# p207 [('Victim', 1)]
# p208 [('Suspect', 1)]
# p209 [('Suspect', 1)]
# p21 [('Witness', 1), ('Victim', 1)]
# p210 [('Suspect', 1)]
# p211 [('Victim', 1)]
# p212 [('Victim Suspect', 1)]
# p213 [('Suspect', 1)]
# p214 [('Victim', 4), ('Suspect', 2), ('Witness', 1)]
# p215 [('Victim', 1)]
# p216 [('Suspect', 2), ('Witness', 1)]
# p217 [('Suspect', 1)]
# p218 [('Suspect', 1)]
# p219 [('Suspect', 2), ('Victim', 1)]
# p22 [('Witness', 1)]
# p220 [('Victim', 9), ('Suspect', 6), ('Witness', 2)]
# p221 [('Victim', 2), ('Victim Suspect', 1), ('Witness', 1)]
# p222 [('Suspect', 1)]
# p223 [('Suspect', 1)]
# p224 [('Victim', 1)]
# p225 [('Suspect', 1), ('Witness', 1), ('Victim', 1)]
# p226 [('Suspect', 1)]
# p227 [('Victim', 1)]
# p228 [('Suspect', 1)]
# p229 [('Victim', 1)]
# p23 [('Victim', 1)]
# p230 [('Witness', 1)]
# p231 [('Suspect', 1)]
# p232 [('Victim', 1)]
# p233 [('Suspect', 1)]
# p234 [('Suspect', 1)]
# p235 [('Witness', 1)]
# p236 [('Suspect', 1)]
# p237 [('Victim', 1)]
# p238 [('Suspect', 1)]
# p239 [('Victim', 1)]
# p24 [('Suspect', 1)]
# p240 [('Suspect', 1)]
# p241 [('Suspect', 1)]
# p242 [('Victim', 3), ('Witness', 1), ('Suspect', 1)]
# p243 [('Suspect', 2)]
# p244 [('Suspect', 2)]
# p245 [('Suspect', 2), ('Victim', 1)]
# p246 [('Victim', 1)]
# p247 [('Suspect', 1), ('Victim', 1)]
# p248 [('Suspect', 1)]
# p249 [('Suspect', 2)]
# p25 [('Suspect', 1)]
# p250 [('Suspect', 1)]
# p251 [('Witness', 1)]
# p252 [('Victim', 1)]
# p253 [('Victim', 1), ('Suspect', 1)]
# p254 [('Suspect', 1)]
# p255 [('Victim', 1)]
# p256 [('Victim', 1)]
# p257 [('Suspect', 1)]
# p258 [('Victim', 1)]
# p259 [('Victim', 1)]
# p26 [('Victim', 1)]
# p260 [('Victim', 1)]
# p261 [('Victim', 1)]
# p262 [('Witness', 1)]
# p263 [('Suspect', 1)]
# p264 [('Suspect', 2)]
# p265 [('Suspect', 1)]
# p266 [('Victim', 1)]
# p267 [('Suspect', 1), ('Victim', 1)]
# p268 [('Suspect', 1)]
# p269 [('Victim', 1), ('Suspect', 1)]
# p27 [('Suspect', 1)]
# p270 [('Victim', 1)]
# p271 [('Victim', 1)]
# p272 [('Suspect', 1)]
# p273 [('Victim', 1)]
# p274 [('Victim', 1)]
# p275 [('Witness', 1)]
# p276 [('Suspect', 1)]
# p277 [('Victim', 3), ('Suspect', 2), ('Witness', 2)]
# p278 [('Witness', 1)]
# p279 [('Suspect', 1)]
# p28 [('Victim', 1)]
# p280 [('Witness', 1)]
# p281 [('Witness', 1)]
# p282 [('Victim', 1)]
# p283 [('Suspect', 2)]
# p284 [('Victim Suspect', 1), ('Suspect', 1)]
# p285 [('Victim', 1)]
# p286 [('Suspect', 1)]
# p287 [('Suspect', 1)]
# p288 [('Victim', 1)]
# p289 [('Suspect', 1)]
# p29 [('Suspect', 1)]
# p290 [('Witness', 1)]
# p291 [('Victim', 4), ('Suspect', 2), ('Witness', 1)]
# p292 [('Suspect', 1)]
# p293 [('Victim', 1)]
# p294 [('Suspect', 2)]
# p295 [('Suspect', 1)]
# p296 [('Suspect', 1)]
# p297 [('Suspect', 2)]
# p298 [('Suspect', 1)]
# p299 [('Suspect', 2)]
# p3 [('Victim', 1)]
# p30 [('Suspect', 1)]
# p300 [('Witness', 1)]
# p301 [('Suspect', 1)]
# p302 [('Witness', 1)]
# p303 [('Suspect', 3)]
# p304 [('Victim', 2), ('Suspect', 2)]
# p305 [('Victim', 2)]
# p306 [('Suspect', 1)]
# p307 [('Victim', 1)]
# p308 [('Victim', 1)]
# p309 [('Suspect', 1)]
# p31 [('Witness', 1)]
# p310 [('Suspect', 1)]
# p311 [('Victim', 1)]
# p312 [('Suspect', 1)]
# p313 [('Suspect', 2)]
# p314 [('Suspect', 1)]
# p315 [('Victim', 1), ('Suspect', 1)]
# p316 [('Suspect', 1)]
# p317 [('Victim', 1)]
# p318 [('Suspect', 1)]
# p319 [('Witness', 1)]
# p32 [('Suspect', 1)]
# p320 [('Victim Suspect', 1)]
# p321 [('Suspect', 1)]
# p322 [('Victim', 1)]
# p323 [('Witness', 1)]
# p324 [('Victim Suspect', 1)]
# p325 [('Suspect', 1)]
# p326 [('Victim', 1), ('Suspect', 1)]
# p327 [('Suspect', 1)]
# p328 [('Victim', 1)]
# p329 [('Suspect', 1)]
# p33 [('Victim', 2)]
# p330 [('Suspect', 1)]
# p331 [('Suspect', 2)]
# p332 [('Suspect', 1)]
# p333 [('Suspect', 2), ('Victim Suspect', 1), ('Victim', 1)]
# p334 [('Victim', 2)]
# p335 [('Suspect', 1), ('Victim', 1)]
# p336 [('Victim', 4), ('Suspect', 3), ('Witness', 2)]
# p337 [('Suspect', 1)]
# p338 [('Victim', 1), ('Suspect', 1)]
# p339 [('Victim', 1)]
# p34 [('Suspect', 1)]
# p340 [('Victim', 1)]
# p341 [('Suspect', 1)]
# p342 [('Witness', 1)]
# p343 [('Suspect', 2), ('Witness', 1), ('Victim', 1)]
# p344 [('Suspect', 2), ('Victim', 2), ('Witness', 1)]
# p345 [('Suspect', 2), ('Victim', 1), ('Witness', 1)]
# p346 [('Suspect', 1)]
# p347 [('Suspect', 1)]
# p348 [('Victim', 1)]
# p349 [('Suspect', 1)]
# p35 [('Victim', 1)]
# p350 [('Suspect', 1)]
# p351 [('Victim', 2), ('Witness', 1), ('Suspect', 1)]
# p352 [('Victim', 2), ('Suspect', 1)]
# p353 [('Suspect', 1)]
# p354 [('Witness', 1), ('Suspect', 1)]
# p355 [('Suspect', 1)]
# p356 [('Victim', 6), ('Suspect', 4), ('Witness', 1)]
# p357 [('Victim', 2)]
# p358 [('Suspect', 1)]
# p359 [('Victim', 1)]
# p36 [('Victim Suspect', 1)]
# p360 [('Suspect', 1)]
# p361 [('Victim', 2)]
# p362 [('Victim', 2), ('Suspect', 1)]
# p363 [('Suspect', 2), ('Victim', 1)]
# p364 [('Witness', 1)]
# p365 [('Suspect', 1), ('Victim', 1)]
# p366 [('Victim', 1)]
# p367 [('Suspect', 1)]
# p368 [('Suspect', 1)]
# p369 [('Suspect', 1)]
# p37 [('Victim', 3), ('Suspect', 3), ('Witness', 1), ('Victim Suspect', 1)]
# p370 [('Victim', 3)]
# p371 [('Victim', 1), ('Suspect', 1)]
# p372 [('Victim', 1)]
# p373 [('Witness', 1)]
# p374 [('Victim', 1)]
# p375 [('Victim', 1)]
# p376 [('Suspect', 1)]
# p377 [('Victim', 1)]
# p378 [('Suspect', 1)]
# p379 [('Witness', 1)]
# p38 [('Suspect', 1)]
# p380 [('Suspect', 1)]
# p381 [('Suspect', 5), ('Witness', 1)]
# p382 [('Suspect', 1)]
# p383 [('Suspect', 1)]
# p384 [('Victim', 3), ('Suspect', 3)]
# p385 [('Victim', 1)]
# p386 [('Victim', 1)]
# p387 [('Suspect', 1)]
# p388 [('Victim', 1)]
# p389 [('Victim', 1)]
# p39 [('Suspect', 1)]
# p390 [('Witness', 1)]
# p391 [('Victim', 1)]
# p392 [('Victim', 2), ('Suspect', 1)]
# p393 [('Suspect', 1)]
# p394 [('Victim', 1)]
# p395 [('Victim', 1)]
# p396 [('Suspect', 3), ('Victim', 1), ('Witness', 1)]
# p397 [('Victim', 2), ('Suspect', 1), ('Witness', 1)]
# p398 [('Suspect', 1), ('Victim', 1)]
# p399 [('Suspect', 1)]
# p4 [('Suspect', 1)]
# p40 [('Suspect', 2)]
# p400 [('Suspect', 1), ('Witness', 1)]
# p401 [('Suspect', 1)]
# p402 [('Suspect', 1)]
# p403 [('Suspect', 1)]
# p404 [('Victim', 6), ('Suspect', 3), ('Witness', 1)]
# p405 [('Victim', 2), ('Suspect', 2)]
# p406 [('Suspect', 1), ('Victim', 1), ('Witness', 1)]
# p407 [('Suspect', 1)]
# p408 [('Suspect', 1)]
# p409 [('Victim', 1)]
# p41 [('Suspect', 2)]
# p410 [('Suspect', 3), ('Victim', 1)]
# p411 [('Suspect', 3)]
# p412 [('Suspect', 2)]
# p413 [('Victim', 4), ('Suspect', 2)]
# p414 [('Victim', 4), ('Witness', 2), ('Suspect', 1)]
# p415 [('Victim', 1), ('Suspect', 1)]
# p416 [('Suspect', 1)]
# p417 [('Suspect', 1)]
# p418 [('Witness', 1), ('Victim', 1)]
# p419 [('Victim', 1)]
# p42 [('Victim', 1)]
# p420 [('Suspect', 1), ('Victim Suspect', 1)]
# p421 [('Suspect', 1)]
# p422 [('Suspect', 1)]
# p423 [('Suspect', 1)]
# p424 [('Victim', 1), ('Witness', 1)]
# p425 [('Suspect', 9), ('Victim', 6), ('Witness', 3)]
# p426 [('Victim', 1)]
# p427 [('Victim', 1)]
# p428 [('Witness', 1)]
# p429 [('Suspect', 1)]
# p43 [('Suspect', 1)]
# p430 [('Suspect', 1)]
# p431 [('Victim', 1)]
# p432 [('Victim Suspect', 1)]
# p433 [('Victim', 1)]
# p434 [('Victim', 1)]
# p435 [('Victim', 2)]
# p436 [('Witness', 1)]
# p437 [('Suspect', 2)]
# p438 [('Suspect', 1)]
# p439 [('Victim', 2), ('Suspect', 1)]
# p44 [('Witness', 1)]
# p440 [('Witness', 1)]
# p441 [('Suspect', 2)]
# p442 [('Victim', 1)]
# p443 [('Witness', 1)]
# p444 [('Victim', 1)]
# p445 [('Suspect', 1)]
# p446 [('Victim', 1)]
# p447 [('Victim', 1)]
# p448 [('Witness', 1)]
# p449 [('Victim', 1), ('Suspect', 1)]
# p45 [('Victim', 2)]
# p450 [('Witness', 1)]
# p451 [('Victim', 1)]
# p452 [('Victim', 3)]
# p453 [('Suspect', 1)]
# p454 [('Victim', 1), ('Suspect', 1)]
# p455 [('Suspect', 1)]
# p456 [('Victim', 1)]
# p457 [('Suspect', 1)]
# p458 [('Victim', 1)]
# p459 [('Suspect', 1)]
# p46 [('Suspect', 1), ('Victim', 1)]
# p460 [('Suspect', 1)]
# p461 [('Victim', 1)]
# p462 [('Victim', 1)]
# p463 [('Suspect', 1)]
# p464 [('Suspect', 1)]
# p465 [('Suspect', 1)]
# p466 [('Suspect', 2), ('Victim', 1)]
# p467 [('Suspect', 1)]
# p468 [('Victim', 1)]
# p469 [('Suspect', 1)]
# p47 [('Witness', 1)]
# p470 [('Victim', 2)]
# p471 [('Victim', 1)]
# p472 [('Victim', 2), ('Suspect', 1)]
# p473 [('Witness', 1)]
# p474 [('Victim', 5), ('Suspect', 3), ('Victim Suspect', 1)]
# p475 [('Suspect', 1)]
# p476 [('Suspect', 2)]
# p477 [('Victim Suspect', 1)]
# p478 [('Victim', 1)]
# p479 [('Suspect', 1)]
# p48 [('Victim', 1), ('Suspect', 1)]
# p480 [('Suspect', 1)]
# p481 [('Victim', 2)]
# p482 [('Witness', 1)]
# p483 [('Witness', 1)]
# p484 [('Victim', 1)]
# p485 [('Victim Suspect', 1)]
# p486 [('Victim', 1)]
# p487 [('Victim', 1)]
# p488 [('Suspect', 1)]
# p489 [('Victim', 1)]
# p49 [('Victim', 1)]
# p490 [('Suspect', 1), ('Victim', 1)]
# p491 [('Victim', 1)]
# p492 [('Witness', 1)]
# p493 [('Victim', 1)]
# p494 [('Victim', 1)]
# p495 [('Suspect', 1)]
# p496 [('Victim', 1)]
# p497 [('Victim', 6), ('Witness', 2), ('Suspect', 1)]
# p498 [('Witness', 1)]
# p499 [('Victim', 1)]
# p5 [('Suspect', 1)]
# p50 [('Victim', 1)]
# p500 [('Suspect', 1)]
# p501 [('Victim', 1)]
# p502 [('Victim', 2), ('Suspect', 2), ('Witness', 1)]
# p503 [('Victim', 1)]
# p504 [('Suspect', 1)]
# p505 [('Suspect', 1)]
# p506 [('Suspect', 1)]
# p507 [('Victim', 1)]
# p508 [('Victim', 1)]
# p509 [('Suspect', 1)]
# p51 [('Suspect', 3), ('Victim', 2), ('Victim Suspect', 1)]
# p510 [('Victim', 1)]
# p511 [('Suspect', 1), ('Victim', 1)]
# p512 [('Victim', 2), ('Suspect', 1)]
# p513 [('Suspect', 1), ('Victim', 1)]
# p514 [('Suspect', 7), ('Victim', 3), ('Victim Suspect', 1)]
# p515 [('Victim', 3), ('Suspect', 1)]
# p516 [('Victim', 1)]
# p517 [('Suspect', 1)]
# p518 [('Suspect', 1)]
# p519 [('Suspect', 1)]
# p52 [('Victim', 1)]
# p520 [('Victim', 1)]
# p521 [('Victim', 1)]
# p522 [('Suspect', 1)]
# p523 [('Victim', 1)]
# p524 [('Suspect', 1), ('Victim', 1)]
# p525 [('Suspect', 1)]
# p526 [('Witness', 1)]
# p527 [('Suspect', 1)]
# p528 [('Suspect', 1)]
# p529 [('Victim', 1)]
# p53 [('Victim', 1)]
# p530 [('Suspect', 1)]
# p531 [('Suspect', 8), ('Victim', 1), ('Witness', 1)]
# p532 [('Suspect', 2)]
# p533 [('Victim', 4), ('Suspect', 2)]
# p534 [('Victim', 1)]
# p535 [('Victim', 1)]
# p536 [('Suspect', 2), ('Victim Suspect', 1), ('Victim', 1), ('Witness', 1)]
# p537 [('Victim', 1)]
# p538 [('Suspect', 1)]
# p539 [('Victim', 1)]
# p54 [('Victim', 2), ('Suspect', 2)]
# p540 [('Suspect', 1)]
# p541 [('Victim', 1)]
# p542 [('Witness', 1)]
# p543 [('Witness', 2), ('Victim', 1)]
# p544 [('Victim', 1)]
# p545 [('Witness', 1)]
# p546 [('Suspect', 1)]
# p547 [('Victim Suspect', 1)]
# p548 [('Witness', 1)]
# p549 [('Victim', 3), ('Suspect', 2), ('Victim Suspect', 2)]
# p55 [('Victim', 1)]
# p550 [('Victim', 1)]
# p551 [('Suspect', 1)]
# p552 [('Victim Suspect', 1)]
# p553 [('Suspect', 1)]
# p554 [('Suspect', 1)]
# p555 [('Suspect', 1)]
# p556 [('Suspect', 1)]
# p557 [('Witness', 1)]
# p558 [('Victim', 1)]
# p559 [('Victim', 1)]
# p56 [('Suspect', 5), ('Victim', 5), ('Witness', 4)]
# p560 [('Suspect', 1)]
# p561 [('Victim', 2)]
# p562 [('Suspect', 1)]
# p563 [('Suspect', 2)]
# p564 [('Victim', 1)]
# p565 [('Victim', 1)]
# p566 [('Victim', 1)]
# p567 [('Suspect', 2), ('Victim', 1)]
# p568 [('Victim', 2)]
# p569 [('Witness', 1)]
# p57 [('Suspect', 2), ('Victim', 1)]
# p570 [('Victim', 1)]
# p571 [('Suspect', 1)]
# p572 [('Victim', 3), ('Suspect', 3), ('Witness', 1)]
# p573 [('Suspect', 1)]
# p574 [('Victim Suspect', 1)]
# p575 [('Suspect', 1)]
# p576 [('Suspect', 1)]
# p577 [('Suspect', 4), ('Witness', 1)]
# p578 [('Suspect', 1)]
# p579 [('Victim', 1)]
# p58 [('Victim', 1), ('Suspect', 1)]
# p580 [('Suspect', 1)]
# p581 [('Witness', 1)]
# p582 [('Victim', 1)]
# p583 [('Witness', 1)]
# p584 [('Suspect', 2), ('Victim Suspect', 1)]
# p585 [('Victim', 1)]
# p586 [('Suspect', 1)]
# p587 [('Suspect', 1)]
# p588 [('Victim', 1)]
# p589 [('Suspect', 1)]
# p59 [('Suspect', 1)]
# p590 [('Suspect', 1)]
# p591 [('Suspect', 1)]
# p592 [('Suspect', 4), ('Victim', 3), ('Victim Suspect', 1), ('Witness', 1)]
# p593 [('Victim', 1)]
# p594 [('Witness', 1)]
# p595 [('Victim', 1)]
# p596 [('Witness', 1)]
# p597 [('Victim', 1)]
# p598 [('Victim', 1)]
# p599 [('Suspect', 1)]
# p6 [('Victim', 1)]
# p60 [('Witness', 1)]
# p600 [('Suspect', 3), ('Victim', 1)]
# p601 [('Victim', 1)]
# p602 [('Suspect', 1)]
# p603 [('Victim Suspect', 1)]
# p604 [('Victim', 1)]
# p605 [('Victim', 1)]
# p606 [('Victim', 1)]
# p607 [('Victim', 1)]
# p608 [('Witness', 1)]
# p609 [('Victim Suspect', 1)]
# p61 [('Victim', 1)]
# p610 [('Victim', 1)]
# p611 [('Suspect', 1)]
# p612 [('Victim', 1)]
# p613 [('Victim', 2), ('Witness', 1)]
# p614 [('Victim', 1)]
# p615 [('Suspect', 1)]
# p616 [('Suspect', 1)]
# p617 [('Suspect', 1)]
# p618 [('Suspect', 1)]
# p619 [('Victim', 1)]
# p62 [('Victim', 4), ('Suspect', 2)]
# p620 [('Suspect', 1)]
# p621 [('Suspect', 1)]
# p622 [('Suspect', 1)]
# p623 [('Suspect', 1)]
# p624 [('Victim', 1)]
# p625 [('Suspect', 1)]
# p626 [('Suspect', 1)]
# p627 [('Suspect', 1)]
# p628 [('Suspect', 1)]
# p629 [('Suspect', 1)]
# p63 [('Suspect', 1)]
# p630 [('Suspect', 1)]
# p631 [('Suspect', 1)]
# p632 [('Victim', 1)]
# p633 [('Suspect', 2)]
# p634 [('Suspect', 1), ('Victim', 1)]
# p635 [('Suspect', 1)]
# p636 [('Suspect', 2), ('Victim', 1)]
# p637 [('Suspect', 2)]
# p638 [('Victim', 1)]
# p639 [('Victim Suspect', 1)]
# p64 [('Suspect', 1)]
# p640 [('Suspect', 1)]
# p641 [('Victim', 1)]
# p642 [('Victim', 3), ('Suspect', 2)]
# p643 [('Suspect', 1)]
# p644 [('Witness', 1)]
# p645 [('Witness', 1)]
# p646 [('Witness', 1)]
# p647 [('Suspect', 1)]
# p648 [('Victim', 1)]
# p649 [('Victim', 1), ('Suspect', 1)]
# p65 [('Suspect', 1)]
# p650 [('Victim', 1)]
# p651 [('Victim', 1)]
# p652 [('Suspect', 1), ('Witness', 1)]
# p653 [('Suspect', 1)]
# p654 [('Suspect', 1)]
# p655 [('Suspect', 1)]
# p656 [('Suspect', 1)]
# p657 [('Victim', 1)]
# p658 [('Suspect', 1)]
# p659 [('Suspect', 4), ('Victim', 3), ('Witness', 2)]
# p66 [('Suspect', 1)]
# p660 [('Victim', 1)]
# p661 [('Suspect', 1)]
# p662 [('Victim', 2)]
# p663 [('Suspect', 3)]
# p664 [('Witness', 1), ('Suspect', 1)]
# p665 [('Suspect', 1)]
# p666 [('Suspect', 2)]
# p667 [('Suspect', 1)]
# p668 [('Victim', 1)]
# p669 [('Suspect', 1)]
# p67 [('Suspect', 4)]
# p670 [('Victim', 1)]
# p671 [('Victim', 1)]
# p672 [('Victim', 1)]
# p673 [('Victim', 1)]
# p674 [('Victim', 1)]
# p675 [('Witness', 1)]
# p676 [('Victim', 1), ('Witness', 1)]
# p677 [('Witness', 1)]
# p678 [('Suspect', 1)]
# p679 [('Victim', 1)]
# p68 [('Suspect', 1)]
# p680 [('Victim', 2), ('Witness', 1), ('Suspect', 1)]
# p681 [('Victim', 2), ('Suspect', 2), ('Witness', 1)]
# p682 [('Victim Suspect', 1)]
# p683 [('Witness', 1)]
# p684 [('Victim', 1)]
# p685 [('Suspect', 1)]
# p686 [('Suspect', 2), ('Victim', 1)]
# p687 [('Victim', 1)]
# p688 [('Victim', 1)]
# p689 [('Victim', 1)]
# p69 [('Victim', 1)]
# p690 [('Suspect', 3), ('Victim', 3), ('Victim Suspect', 1)]
# p691 [('Victim', 1)]
# p692 [('Witness', 1), ('Suspect', 1)]
# p693 [('Suspect', 1)]
# p694 [('Suspect', 1)]
# p695 [('Suspect', 9), ('Victim', 2)]
# p696 [('Suspect', 4), ('Victim', 3), ('Victim Suspect', 1), ('Witness', 1)]
# p697 [('Victim', 1)]
# p698 [('Witness', 1)]
# p699 [('Victim', 1)]
# p7 [('Witness', 1)]
# p70 [('Suspect', 1)]
# p700 [('Witness', 1)]
# p701 [('Suspect', 1)]
# p702 [('Victim', 1), ('Suspect', 1)]
# p703 [('Witness', 1)]
# p704 [('Suspect', 1)]
# p705 [('Suspect', 1)]
# p706 [('Suspect', 1)]
# p707 [('Suspect', 1)]
# p708 [('Suspect', 1)]
# p709 [('Victim', 1)]
# p71 [('Witness', 1)]
# p710 [('Suspect', 1)]
# p711 [('Suspect', 1)]
# p712 [('Witness', 1)]
# p713 [('Witness', 1)]
# p714 [('Suspect', 1)]
# p715 [('Suspect', 6), ('Victim', 6)]
# p716 [('Suspect', 1)]
# p717 [('Suspect', 1)]
# p718 [('Victim', 1)]
# p719 [('Suspect', 2), ('Victim', 1)]
# p72 [('Victim', 1)]
# p720 [('Suspect', 1)]
# p721 [('Victim', 1)]
# p722 [('Witness', 1)]
# p723 [('Suspect', 2), ('Victim', 1)]
# p724 [('Suspect', 1)]
# p725 [('Suspect', 1)]
# p726 [('Witness', 1)]
# p727 [('Victim', 1)]
# p728 [('Victim', 1)]
# p729 [('Suspect', 4), ('Victim', 3), ('Witness', 1)]
# p73 [('Witness', 1), ('Suspect', 1)]
# p730 [('Victim', 1)]
# p731 [('Witness', 1), ('Victim', 1)]
# p732 [('Witness', 1)]
# p733 [('Suspect', 1)]
# p734 [('Victim', 1)]
# p735 [('Suspect', 1)]
# p736 [('Witness', 3), ('Victim Suspect', 1), ('Victim', 1), ('Suspect', 1)]
# p737 [('Witness', 1)]
# p738 [('Suspect', 1)]
# p739 [('Witness', 1), ('Suspect', 1)]
# p74 [('Suspect', 5), ('Victim', 2)]
# p740 [('Suspect', 2), ('Victim', 1)]
# p741 [('Witness', 1)]
# p742 [('Suspect', 1)]
# p743 [('Witness', 1)]
# p744 [('Suspect', 2)]
# p745 [('Suspect', 1)]
# p746 [('Suspect', 2), ('Witness', 1)]
# p747 [('Witness', 1)]
# p748 [('Victim', 1)]
# p749 [('Suspect', 1)]
# p75 [('Witness', 1)]
# p750 [('Suspect', 1)]
# p751 [('Suspect', 1)]
# p752 [('Victim', 1)]
# p753 [('Victim', 1)]
# p754 [('Suspect', 1)]
# p755 [('Suspect', 1)]
# p756 [('Victim', 1)]
# p757 [('Witness', 1)]
# p758 [('Suspect', 2)]
# p759 [('Suspect', 1)]
# p76 [('Victim', 1)]
# p760 [('Victim', 1)]
# p761 [('Victim', 1)]
# p762 [('Victim', 1)]
# p763 [('Victim', 1), ('Suspect', 1), ('Witness', 1), ('Victim Suspect', 1)]
# p764 [('Witness', 1), ('Victim', 1), ('Suspect', 1)]
# p765 [('Suspect', 1)]
# p766 [('Suspect', 1)]
# p767 [('Victim', 3), ('Suspect', 2), ('Witness', 1)]
# p768 [('Suspect', 1)]
# p769 [('Witness', 1)]
# p77 [('Victim', 1), ('Victim Suspect', 1)]
# p770 [('Suspect', 1)]
# p771 [('Victim', 1)]
# p772 [('Witness', 1)]
# p773 [('Suspect', 1)]
# p774 [('Suspect', 1), ('Victim', 1)]
# p775 [('Victim', 2)]
# p776 [('Suspect', 1), ('Witness', 1)]
# p777 [('Victim', 1)]
# p778 [('Suspect', 1), ('Victim', 1)]
# p779 [('Victim', 1), ('Suspect', 1)]
# p78 [('Witness', 2)]
# p780 [('Suspect', 1)]
# p781 [('Suspect', 1)]
# p782 [('Suspect', 1)]
# p783 [('Suspect', 1), ('Witness', 1)]
# p784 [('Victim', 1)]
# p785 [('Suspect', 1)]
# p786 [('Witness', 1)]
# p787 [('Victim', 1)]
# p788 [('Suspect', 3), ('Witness', 1), ('Victim', 1)]
# p789 [('Suspect', 1)]
# p79 [('Witness', 5), ('Victim', 1)]
# p790 [('Victim Suspect', 1)]
# p791 [('Suspect', 1)]
# p792 [('Victim', 1)]
# p793 [('Victim', 2)]
# p794 [('Victim Suspect', 1)]
# p795 [('Victim', 1)]
# p796 [('Witness', 1)]
# p797 [('Victim', 3), ('Witness', 2), ('Suspect', 2)]
# p798 [('Victim', 1)]
# p799 [('Victim Suspect', 1)]
# p8 [('Victim', 1)]
# p80 [('Victim', 1)]
# p800 [('Witness', 1)]
# p801 [('Suspect', 1)]
# p802 [('Suspect', 1)]
# p803 [('Witness', 1)]
# p804 [('Suspect', 1)]
# p805 [('Victim', 1)]
# p806 [('Victim', 1)]
# p807 [('Victim', 1)]
# p808 [('Suspect', 1)]
# p809 [('Suspect', 2), ('Witness', 1)]
# p81 [('Suspect', 1)]
# p810 [('Suspect', 1)]
# p811 [('Victim', 3), ('Suspect', 2)]
# p812 [('Suspect', 2), ('Victim', 1), ('Witness', 1)]
# p813 [('Victim', 1)]
# p814 [('Victim', 1)]
# p815 [('Suspect', 12), ('Victim', 11), ('Witness', 2)]
# p816 [('Suspect', 1)]
# p817 [('Victim', 1)]
# p818 [('Suspect', 2), ('Victim', 1)]
# p819 [('Suspect', 1)]
# p82 [('Suspect', 2), ('Victim', 1)]
# p820 [('Suspect', 1)]
# p821 [('Victim', 1), ('Suspect', 1)]
# p822 [('Victim', 1)]
# p823 [('Suspect', 1)]
# p824 [('Victim', 1)]
# p825 [('Suspect', 1)]
# p826 [('Victim', 1)]
# p827 [('Victim', 1)]
# p828 [('Suspect', 1)]
# p829 [('Suspect', 1)]
# p83 [('Victim', 1)]
# p84 [('Suspect', 1)]
# p85 [('Suspect', 1)]
# p86 [('Suspect', 1)]
# p87 [('Suspect', 2), ('Victim', 1), ('Witness', 1)]
# p88 [('Victim', 3), ('Suspect', 2), ('Victim Suspect', 2), ('Witness', 1)]
# p89 [('Witness', 1), ('Suspect', 1), ('Victim', 1)]
# p9 [('Suspect', 1)]
# p90 [('Victim', 1)]
# p91 [('Victim', 1)]
# p92 [('Victim', 1)]
# p93 [('Victim', 1)]
# p94 [('Victim', 1)]
# p95 [('Victim', 1)]
# p96 [('Suspect', 1)]
# p97 [('Suspect', 2)]
# p98 [('Witness', 1)]
# p99 [('Victim', 1)]

# %%
top_nodes = {n for n, d in G.nodes(data=True) if d["bipartite"] == 0}
bottom_nodes = set(G) - top_nodes

P = bipartite.weighted_projected_graph(G, top_nodes)

Pcc = sorted(nx.connected_components(P), key=len, reverse=True)
P0 = P.subgraph(Pcc[0])
len(P0.nodes), len(P0.edges)
# Out:
# (754, 2127)

# %%
nx.draw_spring(P0, node_size=20)

# %%
#P0 = G0

import networkx.algorithms.community as nxcom
communities = sorted(nxcom.greedy_modularity_communities(P0), key=len, reverse=True) #30 coms modularity 0.845
#communities = sorted(nxcom.label_propagation_communities(P0), key=len, reverse=True) #89 coms modularity 0.787

# Count the communities
print(f"There are {len(communities)} communities.")

nxcom.modularity(P0, communities)
# Out:
# There are 30 communities.
# 0.8451203372057261

# %%
comms = P.subgraph(communities[0])
len(comms.nodes)

nx.draw_spring(comms, node_size=20)

# %%
'''Code from: https://orbifold.net/default/community-detection-using-networkx/'''

def set_node_community(G, communities):
    '''Add community to node attributes'''
    for c, v_c in enumerate(communities):
        for v in v_c:
            # Add 1 to save 0 for external edges
            G.nodes[v]['community'] = c + 1

def set_edge_community(G):
    '''Find internal edges and add their community to their attributes'''
    for v, w, in G.edges:
        if G.nodes[v]['community'] == G.nodes[w]['community']:
            # Internal edge, mark with community
            G.edges[v, w]['community'] = G.nodes[v]['community']
        else:
            # External edge, mark as 0
            G.edges[v, w]['community'] = 0

def get_color(i, r_off=1, g_off=1, b_off=1):
    '''Assign a color to a vertex.'''
    r0, g0, b0 = 0, 0, 0
    n = 16
    low, high = 0.1, 0.9
    span = high - low
    r = low + span * (((i + r_off) * 3) % n) / (n - 1)
    g = low + span * (((i + g_off) * 5) % n) / (n - 1)
    b = low + span * (((i + b_off) * 7) % n) / (n - 1)
    return (r, g, b)

# %%
# Set node and edge communities
set_node_community(P0, communities)
set_edge_community(P0)

node_color = [get_color(P0.nodes[v]['community']) for v in P0.nodes]

# Set community color for edges between members of the same community (internal) and intra-community edges (external)
external = [(v, w) for v, w in P0.edges if P0.edges[v, w]['community'] == 0]
internal = [(v, w) for v, w in P0.edges if P0.edges[v, w]['community'] > 0]
internal_color = ['black' for e in internal]

# %%
P_pos = nx.spring_layout(P0)

plt.rcParams.update({'figure.figsize': (30, 20)})

# Draw external edges

nx.draw_networkx(
    P0,
    pos=P_pos,
    node_size=5,
    edgelist=external,
    edge_color="silver",
    with_labels=False)

# Draw nodes and internal edges

nx.draw_networkx(
    P0,
    pos=P_pos,
    node_color=node_color,
    edgelist=internal,
    edge_color=internal_color,
    with_labels=False)

# %%
len(set(node_color))
# Out:
# 16
